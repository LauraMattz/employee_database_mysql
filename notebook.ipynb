# %% [markdown]
# # Database de Colaboradores do MySQL
#
# Análises com o Database de Colaboradores do MySQL

# %%
from IPython.display import display
from PIL import Image

# Open the image file
im = Image.open('DALL·E 2023-01-02 19.34.16 - work modern colorfull.png')

# Display the image
display(im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %% [markdown]
# ### Total de Colaboradores

# %%
SELECT COUNT(emp_no) as total_employees from employees
# Out:
#    total_employees
# 0           300024

# %% [markdown]
# ### Análise por Gênero

# %% [markdown]
# Total de colaboradores por Gênero

# %%
SELECT round(count(first_name)) as total_per_gender, gender from employees
group by gender
# Out:
#    total_per_gender gender
# 0            179973      M
# 1            120051      F

# %%
import plotly.express as px
import pandas as pd


# Create a bar chart using Plotly
fig = px.bar(df, x='gender', y='total_per_gender', color='gender')

# Create labels and show plot
fig.update_layout(
    title="Total Colaboradores por Gênero<br><sup>",
    title_x=0.5,
    xaxis_title="Gênero",
    yaxis_title="Total",
    legend_title="Gender",
    template="plotly_dark",
)
fig.show()
# Out:
# <div>                            <div id="1698838f-3509-44a6-9d78-8d75c9a318d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1698838f-3509-44a6-9d78-8d75c9a318d3")) {                    Plotly.newPlot(                        "1698838f-3509-44a6-9d78-8d75c9a318d3",                        [{"alignmentgroup":"True","hovertemplate":"gender=%{x}<br>total_per_gender=%{y}<extra></extra>","legendgroup":"M","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"textposition":"auto","x":["M"],"xaxis":"x","y":[179973],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}<br>total_per_gender=%{y}<extra></extra>","legendgroup":"F","marker":{"color":"#EF553B","pattern":{"s
# ...

# %% [markdown]
# ### Média Salarial por Gênero

# %%
SELECT round(avg(salary)) as avg_salary_per_gender, gender from employees emp
LEFT JOIN salaries sal on sal.emp_no = emp.emp_no
group by gender
# Out:
#    avg_salary_per_gender gender
# 0                  63838      M
# 1                  63770      F

# %%
import plotly.express as px
import pandas as pd

fig = px.bar(df, x='gender', y='avg_salary_per_gender', color='gender')


# Create labels and show plot
fig.update_layout(
    title="Salário Médio por Gênero<br><sup>",
    title_x=0.5,
    xaxis_title="Gênero",
    yaxis_title="Total",
    legend_title="Gênero",
    template="plotly_dark",
)

fig.show()
# Out:
# <div>                            <div id="a21ea307-ad4a-43ec-81f3-1f4fbf579d62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a21ea307-ad4a-43ec-81f3-1f4fbf579d62")) {                    Plotly.newPlot(                        "a21ea307-ad4a-43ec-81f3-1f4fbf579d62",                        [{"alignmentgroup":"True","hovertemplate":"gender=%{x}<br>avg_salary_per_gender=%{y}<extra></extra>","legendgroup":"M","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"textposition":"auto","x":["M"],"xaxis":"x","y":[63838],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}<br>avg_salary_per_gender=%{y}<extra></extra>","legendgroup":"F","marker":{"color":"#EF553B","pat
# ...

# %% [markdown]
# ### Média Salarial por Cargo

# %%
SELECT round(avg(salary)) as avg_salary, title FROM salaries sal
left join titles tit on tit.emp_no = sal.emp_no
group by title
order by avg_salary desc
# Out:
#    avg_salary               title
# 0       70471        Senior Staff
# 1       69309               Staff
# 2       66924             Manager
# 3       60543     Senior Engineer
# 4       59508            Engineer
# 5       59305  Assistant Engineer
# 6       59294    Technique Leader

# %%
# Import libraries
import pandas as pd
import plotly.express as px

# Create bar chart
fig = px.bar(df,x="avg_salary", y="title", color="title")

# Create labels and show plot
fig.update_layout(
    title="Média de Salário por Cargo<br><sup>",
    title_x=0.5,
    xaxis_title="Salário Médio",
    yaxis_title="Cargo",
    legend_title="Cargo",
    template="plotly_dark",
)
fig.show()
# Out:
# <div>                            <div id="7c4bbec7-3328-42be-95b3-7bb61dbea6ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c4bbec7-3328-42be-95b3-7bb61dbea6ce")) {                    Plotly.newPlot(                        "7c4bbec7-3328-42be-95b3-7bb61dbea6ce",                        [{"alignmentgroup":"True","hovertemplate":"title=%{y}<br>avg_salary=%{x}<extra></extra>","legendgroup":"Senior Staff","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Senior Staff","offsetgroup":"Senior Staff","orientation":"h","showlegend":true,"textposition":"auto","x":[70471],"xaxis":"x","y":["Senior Staff"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"title=%{y}<br>avg_salary=%{x}<extra></extra>","legendgroup":"Staff","marker"
# ...
